# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

columns = [
    "Acc_Date",
    "Acc_No",
    "Title",
    "ISBN",
    "Author_Editor",
    "Edition_Volume",
    "Place_Publisher",
    "Year",
    "Pages",
    "Class_No"
]

df = pd.read_csv(
    "dau_library_data.csv",
    usecols=range(len(columns)),  
    names=columns,
    header=0,
    encoding='latin1'
)

print(df.sample(5))
# Out:
#          Acc_Date  Acc_No                                              Title           ISBN      Author_Editor Edition_Volume                          Place_Publisher    Year          Pages      Class_No
# 32728  23-12-2021   32729  Structure of emotions : investigations in cogn...  9780521395687  Gordon, Robert M.            NaN  Cambridge : Cambridge University Press,  1990.0  xiv, 161 p. ;     152.4 GOR
# 34372  06-10-2023   34373              Hyperconnectivity and its discontents  9781509554539   Brubaker, Rogers            NaN                Cambridge : Polity Press,  2023.0   xi, 264 p. ;  303.4833 BRU
# 22199  29-05-2009   22200  Repentance of Nussooh = Taubat-al-Nasuh : the ...     8178240769       Ahmad, Nazir            NaN                  Delhi: Permanent Black,  2004.0   xiv, 140 p.;  891.4393 NAZ
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36358 entries, 0 to 36357
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Acc_Date         36179 non-null  object
#  1   Acc_No           36358 non-null  int64
#  2   Title            36358 non-null  object
#  3   ISBN             36358 non-null  object
#  4   Author_Editor    36295 non-null  object
#  5   Edition_Volume   5779 non-null   object
#  6   Place_Publisher  36358 non-null  object
#  7   Year             36188 non-null  float64
#  8   Pages            36357 non-null  object
#  9   Class_No         36358 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 2.8+ MB

# %%
df.shape
# Out:
# (36358, 10)
