# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

columns = [
    "Acc_Date",
    "Acc_No",
    "Title",
    "ISBN",
    "Author_Editor",
    "Edition_Volume",
    "Place_Publisher",
    "Year",
    "Pages",
    "Class_No"
]

df = pd.read_csv(
    "D:\\COLLAGE\\DAIICT\\2 - SEM\\BDE\\Project\\Big-Data-Engineering-\\Data\\raw_data\\dau_library_data.csv",
    usecols=range(len(columns)),  
    names=columns,
    header=0,
    encoding='latin1'
)

print("shape of data is ",df.shape)
print("\n")

print("Sample Data Is :")
print(df.sample(5))
print("\n")

print("Data Information Is : ")
df.info()
# Out:
# shape of data is  (36358, 10)
#
#
# Sample Data Is :
#          Acc_Date  Acc_No                               Title           ISBN  \
# 26195  13-08-2011   26196          Introduction to algorithms  9788120340077
# 33741  31-03-2023   33742  Introduction to python programming  9780367410179
# 3928   29-10-2002    3929           Beginning Java Networking     8173663998
# 17846  16-11-2007   17847                Geometry and meaning     1575864487
# 34790  01-03-2024   34791          Topics in abstract algebra  9789393330246
#
#            Author_Editor Edition_Volume  \
# 26195  Cormen, Thomas H.        3rd ed.
# 33741   S,. Gowrishankar            NaN
# 3928         Darby, Chad            NaN
# 17846   Widdows, Dominic            NaN
# 34790          Sen, M. K        4th ed.
#
#                                          Place_Publisher    Year  \
# 26195                           New Delhi: PHI Learning,  2011.0
# 33741                            Boca Raton : CRC Press,  2019.0
# ...
